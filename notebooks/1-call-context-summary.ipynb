# %% [markdown]
# # Call Context Summary

# %%
import json
import pathlib
import copy

# %%
data_dir = pathlib.Path.cwd().parent / "data"
trace_file = data_dir / "fibonacci" / "paptrace.json"
with open(trace_file, "r") as f_in:
    traces = json.load(f_in)["traces"]

# %%
def populate_sig_map(tree, sig_map):
    if isinstance(tree, list):
        for item in tree:
            populate_sig_map(item, sig_map)
    elif isinstance(tree, dict):
        if "sig" in tree:
            k = tree["sig"]
            if k not in sig_map:
                sig_map[k] = len(sig_map)
        for key, value in tree.items():
            populate_sig_map(value, sig_map)

sig_map = {}
populate_sig_map(traces, sig_map)
print(f"Number of unique signatures: {len(sig_map)}")
display(sig_map)
# Out:
# Number of unique signatures: 6
# {'unsigned long long fibonacci::RecursiveNaive(unsigned short)': 0,
#  'unsigned long long fibonacci::RecursiveMemo(unsigned short)': 1,
#  'reference std::vector<unsigned long long>::operator[](size_type)': 2,
#  'unsigned long long fibonacci::(anonymous namespace)::RecursiveMemoImpl(unsigned short, std::vector<unsigned long long> &)': 3,
#  'unsigned long long fibonacci::Iterative(unsigned short)': 4,
#  'unsigned long long fibonacci::LookupTable(unsigned short)': 5}

# %%
def extract_call_nodes(tree, sig_map, call_nodes):
    if isinstance(tree, list):
        for item in tree:
            extract_call_nodes(item, sig_map, call_nodes)
    elif isinstance(tree, dict):
        for key, value in tree.items():
            extract_call_nodes(value, sig_map, call_nodes)
        if "type" in tree and "Call" in tree["type"]:
            tree["id"] = sig_map[tree["sig"]]
            call_nodes.append(copy.deepcopy(tree))
            tree.pop("children")

call_nodes = []
extract_call_nodes(traces, sig_map, call_nodes)
print(f"Number of call nodes: {len(call_nodes)}")
display(call_nodes[:3])
# Out:
# Number of call nodes: 288
# [{'children': [{'children': [{'children': [],
#       'desc': 'return n',
#       'id': 2106007,
#       'type': 'ReturnStmt'}],
#     'desc': 'n < 2',
#     'id': 2106009,
#     'type': 'IfThenStmt'}],
#   'id': 0,
#   'params': [{'name': 'n', 'value': '0'}],
#   'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#   'type': 'CalleeExpr'},
#  {'children': [{'children': [{'children': [],
#       'desc': 'return n',
#       'id': 2106007,
#       'type': 'ReturnStmt'}],
#     'desc': 'n < 2',
#     'id': 2106009,
#     'type': 'IfThenStmt'}],
#   'id': 0,
#   'params': [{'name': 'n', 'value': '1'}],
#   'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#   'type': 'CalleeExpr'},
#  {'children': [{'children': [{'children': [],
#       'desc': 'return n',
#       'id': 2106007,
#       'type': 'ReturnStmt'}],
#     'desc': 'n < 2',
#     'id': 2106009,
#     'type': 'IfThenStmt'}],
#   'id': 0,
#   'params': [{'name': 'n', 'value': '1'}],
#   'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#   'type': 'CalleeExpr'}]

# %%
unique_call_nodes = []
unique_call_node_strs = {}
for call_node in call_nodes:
    call_node_str = str(call_node)
    if not call_node_str in unique_call_node_strs:
        unique_call_node_strs[call_node_str] = 1
        unique_call_nodes.append(call_node)

print(f"Number of uniq. call nodes: {len(unique_call_nodes)}")
display(unique_call_nodes[:3])
# Out:
# Number of uniq. call nodes: 162
# [{'children': [{'children': [{'children': [],
#       'desc': 'return n',
#       'id': 2106007,
#       'type': 'ReturnStmt'}],
#     'desc': 'n < 2',
#     'id': 2106009,
#     'type': 'IfThenStmt'}],
#   'id': 0,
#   'params': [{'name': 'n', 'value': '0'}],
#   'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#   'type': 'CalleeExpr'},
#  {'children': [{'children': [{'children': [],
#       'desc': 'return n',
#       'id': 2106007,
#       'type': 'ReturnStmt'}],
#     'desc': 'n < 2',
#     'id': 2106009,
#     'type': 'IfThenStmt'}],
#   'id': 0,
#   'params': [{'name': 'n', 'value': '1'}],
#   'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#   'type': 'CalleeExpr'},
#  {'children': [{'children': [{'id': 0,
#       'params': [{'name': 'n', 'value': '1'}],
#       'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#       'type': 'CalleeExpr'},
#      {'id': 0,
#       'params': [{'name': 'n', 'value': '0'}],
#       'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#       'type': 'CalleeExpr'}],
#     'desc': 'return RecursiveNaive(n - 1) + RecursiveNaive(n - 2)',
#     'id': 2106188,
#     'type': 'ReturnStmt'}],
#   'id': 0,
#   'params': [{'name': 'n', 'value': '2'}],
#   'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#   'type': 'CalleeExpr'}]

# %%
call_map = {}
for call_node in unique_call_nodes:
    id = call_node["id"]
    if not id in call_map:
        call_map[id] = {"sig": call_node["sig"], "ctxs": {}}
    ctx = str(call_node["params"])
    if not ctx in call_map[id]["ctxs"]:
        call_map[id]["ctxs"][ctx] = len(call_map[id]["ctxs"])
    else:
        raise Exception(f"Duplicate call node ctx: {ctx}!")
        
print(f"Number of top-level call map entries: {len(call_map)}")
display(call_map)
# Out:
# Number of top-level call map entries: 6
# {0: {'sig': 'unsigned long long fibonacci::RecursiveNaive(unsigned short)',
#   'ctxs': {"[{'name': 'n', 'value': '0'}]": 0,
#    "[{'name': 'n', 'value': '1'}]": 1,
#    "[{'name': 'n', 'value': '2'}]": 2,
#    "[{'name': 'n', 'value': '3'}]": 3,
#    "[{'name': 'n', 'value': '4'}]": 4,
#    "[{'name': 'n', 'value': '5'}]": 5,
#    "[{'name': 'n', 'value': '6'}]": 6,
#    "[{'name': 'n', 'value': '7'}]": 7,
#    "[{'name': 'n', 'value': '94'}]": 8}},
#  2: {'sig': 'reference std::vector<unsigned long long>::operator[](size_type)',
#   'ctxs': {"[{'name': 'memo', 'value': '{ 0 }'}, {'name': '1', 'value': '1'}]": 0,
#    "[{'name': 'memo', 'value': '{ 0 }'}, {'name': 'n', 'value': '0'}]": 1,
#    "[{'name': 'memo', 'value': '{ 0, 0 }'}, {'name': '1', 'value': '1'}]": 2,
#    "[{'name': 'memo', 'value': '{ 0, 1 }'}, {'name': 'n', 'value': '1'}]": 3,
#    "[{'name': 'memo', 'value': '{ 0, 0, 0 }'}, {'name': '1', 'value': '1'}]": 4,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0 }'}, {'name': 'n', 'value': '2'}]": 5,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0 }'}, {'name': 'n', 'value': '0'}]": 6,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0 }'}, {'name': 'n', 'value': '1'}]": 7,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1 }'}, {'name': 'n', 'value': '2'}]": 8,
#    "[{'name': 'memo', 'value': '{ 0, 0, 0, 0 }'}, {'name': '1', 'value': '1'}]": 9,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 10,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}, {'name': 'n', 'value': '1'}]": 11,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 12,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}, {'name': 'n', 'value': '0'}]": 13,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0 }'}, {'name': 'n', 'value': '2'}]": 14,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0 }'}, {'name': 'n', 'value': '3'}]": 15,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2 }'}, {'name': 'n', 'value': '3'}]": 16,
#    "[{'name': 'memo', 'value': '{ 0, 0, 0, 0, 0 }'}, {'name': '1', 'value': '1'}]": 17,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 18,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 19,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}, {'name': 'n', 'value': '0'}]": 20,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}, {'name': 'n', 'value': '1'}]": 21,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 22,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 23,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0 }'}, {'name': 'n', 'value': '1'}]": 24,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0 }'}, {'name': 'n', 'value': '3'}]": 25,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0 }'}, {'name': 'n', 'value': '4'}]": 26,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3 }'}, {'name': 'n', 'value': '4'}]": 27,
#    "[{'name': 'memo', 'value': '{ 0, 0, 0, 0, 0, 0 }'}, {'name': '1', 'value': '1'}]": 28,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '5'}]": 29,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 30,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '1'}]": 31,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 32,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '0'}]": 33,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 34,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 35,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 36,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 37,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 38,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0 }'}, {'name': 'n', 'value': '4'}]": 39,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0 }'}, {'name': 'n', 'value': '5'}]": 40,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5 }'}, {'name': 'n', 'value': '5'}]": 41,
#    "[{'name': 'memo', 'value': '{ 0, 0, 0, 0, 0, 0, 0 }'}, {'name': '1', 'value': '1'}]": 42,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '6'}]": 43,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 44,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 45,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '0'}]": 46,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '1'}]": 47,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 48,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 49,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '1'}]": 50,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 51,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 52,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 53,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0 }'}, {'name': 'n', 'value': '5'}]": 54,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 55,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0 }'}, {'name': 'n', 'value': '5'}]": 56,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0 }'}, {'name': 'n', 'value': '6'}]": 57,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 8 }'}, {'name': 'n', 'value': '6'}]": 58,
#    "[{'name': 'memo', 'value': '{ 0, 0, 0, 0, 0, 0, 0, 0 }'}, {'name': '1', 'value': '1'}]": 59,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '7'}]": 60,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '5'}]": 61,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 62,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '1'}]": 63,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 64,
#    "[{'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '0'}]": 65,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 66,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 67,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '3'}]": 68,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 69,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0, 0 }'}, {'name': 'n', 'value': '2'}]": 70,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 71,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0, 0 }'}, {'name': 'n', 'value': '5'}]": 72,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0, 0 }'}, {'name': 'n', 'value': '5'}]": 73,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0, 0 }'}, {'name': 'n', 'value': '6'}]": 74,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0, 0 }'}, {'name': 'n', 'value': '4'}]": 75,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 8, 0 }'}, {'name': 'n', 'value': '6'}]": 76,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 8, 0 }'}, {'name': 'n', 'value': '7'}]": 77,
#    "[{'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 8, 13 }'}, {'name': 'n', 'value': '7'}]": 78}},
#  3: {'sig': 'unsigned long long fibonacci::(anonymous namespace)::RecursiveMemoImpl(unsigned short, std::vector<unsigned long long> &)',
#   'ctxs': {"[{'name': 'n', 'value': '0'}, {'name': 'memo', 'value': '{ 0 }'}]": 0,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1 }'}]": 1,
#    "[{'name': 'n', 'value': '0'}, {'name': 'memo', 'value': '{ 0, 1, 0 }'}]": 2,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 0 }'}]": 3,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 0 }'}]": 4,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}]": 5,
#    "[{'name': 'n', 'value': '0'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}]": 6,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}]": 7,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0 }'}]": 8,
#    "[{'name': 'n', 'value': '0'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}]": 9,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}]": 10,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}]": 11,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 1, 0, 0 }'}]": 12,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 1, 0, 0 }'}]": 13,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 1, 0, 0 }'}]": 14,
#    "[{'name': 'n', 'value': '4'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0 }'}]": 15,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}]": 16,
#    "[{'name': 'n', 'value': '0'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}]": 17,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}]": 18,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}]": 19,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0 }'}]": 20,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0 }'}]": 21,
#    "[{'name': 'n', 'value': '4'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0 }'}]": 22,
#    "[{'name': 'n', 'value': '5'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0 }'}]": 23,
#    "[{'name': 'n', 'value': '0'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}]": 24,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}]": 25,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}]": 26,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0 }'}]": 27,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0 }'}]": 28,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 1, 0, 0, 0, 0 }'}]": 29,
#    "[{'name': 'n', 'value': '4'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}]": 30,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0 }'}]": 31,
#    "[{'name': 'n', 'value': '4'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0 }'}]": 32,
#    "[{'name': 'n', 'value': '5'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 0, 0 }'}]": 33,
#    "[{'name': 'n', 'value': '6'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0 }'}]": 34,
#    "[{'name': 'n', 'value': '1'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}]": 35,
#    "[{'name': 'n', 'value': '0'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}]": 36,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}]": 37,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}]": 38,
#    "[{'name': 'n', 'value': '2'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0, 0 }'}]": 39,
#    "[{'name': 'n', 'value': '3'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0, 0 }'}]": 40,
#    "[{'name': 'n', 'value': '4'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 0, 0, 0, 0 }'}]": 41,
#    "[{'name': 'n', 'value': '5'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}]": 42,
#    "[{'name': 'n', 'value': '4'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0, 0 }'}]": 43,
#    "[{'name': 'n', 'value': '5'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0, 0 }'}]": 44,
#    "[{'name': 'n', 'value': '6'}, {'name': 'memo', 'value': '{ 0, 1, 1, 2, 3, 5, 0, 0 }'}]": 45,
#    "[{'name': 'n', 'value': '7'}, {'name': 'memo', 'value': '{ 0, 1, 0, 0, 0, 0, 0, 0 }'}]": 46}},
#  1: {'sig': 'unsigned long long fibonacci::RecursiveMemo(unsigned short)',
#   'ctxs': {"[{'name': 'n', 'value': '0'}]": 0,
#    "[{'name': 'n', 'value': '1'}]": 1,
#    "[{'name': 'n', 'value': '2'}]": 2,
#    "[{'name': 'n', 'value': '3'}]": 3,
#    "[{'name': 'n', 'value': '4'}]": 4,
#    "[{'name': 'n', 'value': '5'}]": 5,
#    "[{'name': 'n', 'value': '6'}]": 6,
#    "[{'name': 'n', 'value': '7'}]": 7,
#    "[{'name': 'n', 'value': '94'}]": 8}},
#  4: {'sig': 'unsigned long long fibonacci::Iterative(unsigned short)',
#   'ctxs': {"[{'name': 'n', 'value': '0'}]": 0,
#    "[{'name': 'n', 'value': '1'}]": 1,
#    "[{'name': 'n', 'value': '2'}]": 2,
#    "[{'name': 'n', 'value': '3'}]": 3,
#    "[{'name': 'n', 'value': '4'}]": 4,
#    "[{'name': 'n', 'value': '5'}]": 5,
#    "[{'name': 'n', 'value': '6'}]": 6,
#    "[{'name': 'n', 'value': '7'}]": 7,
#    "[{'name': 'n', 'value': '94'}]": 8}},
#  5: {'sig': 'unsigned long long fibonacci::LookupTable(unsigned short)',
#   'ctxs': {"[{'name': 'n', 'value': '0'}]": 0,
#    "[{'name': 'n', 'value': '1'}]": 1,
#    "[{'name': 'n', 'value': '2'}]": 2,
#    "[{'name': 'n', 'value': '3'}]": 3,
#    "[{'name': 'n', 'value': '4'}]": 4,
#    "[{'name': 'n', 'value': '5'}]": 5,
#    "[{'name': 'n', 'value': '6'}]": 6,
#    "[{'name': 'n', 'value': '7'}]": 7,
#    "[{'name': 'n', 'value': '94'}]": 8}}}
